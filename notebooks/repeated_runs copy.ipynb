# %% [markdown]
# # Duplicate of sampling.ipynb for doing repeated runs

# %% [markdown]
# ## 0.1. Imports and load data

# %%
import ase.io
import os
from pathlib import Path
import numpy as np
import importlib
import torch
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

from mace import modules
from mace.data.atom_data_loader import AtomDataLoaderBuilder
from mace.testing import Tester, extract_latent_space
from mace.training import FreezeStrategy, NaiveStrategy, Trainer, initialise_autoencoder

import sampling_methods.descriptors as descriptors
import sampling_methods.selectors as selectors
import utils.training as training

importlib.reload(descriptors)
importlib.reload(selectors)
importlib.reload(training)

MAX_EPOCHS = 50
R_MAX = 5.0
BATCH_SIZE = 16
BASE_LR = 1.0e-3
TRANSFER_LR = 5.0e-4
DEVICE = torch.device("cpu")

# define wrapper classes
trainer = Trainer(
    max_epochs=MAX_EPOCHS, early_stopping=True, patience=15,
    restore_best=True, device=DEVICE, verbose=True,
)
data_builder = AtomDataLoaderBuilder(
    cutoff=R_MAX, energy_key="REF_energy", forces_key="REF_forces"
)
tester = Tester(device=DEVICE)
loss_fn = modules.InvariantsWeightedEnergyForcesNacsDipoleLoss(
    energy_weight=1.0, forces_weight=5.0, dipoles_weight=0.0,
    nacs_weight=0.0, socs_weight=0.0,
).to(DEVICE)

# %%
ROOT_PATH = Path.cwd()
DATA_DIR = ROOT_PATH / "../data"

# dataset for training the base model, ie foundation/pre-trained model
BASE_XYZ = DATA_DIR / "A02_propene_grid_static_2e2o.xyz"
BASE_N_GEOMETRIES = '3731'  # number of geometries to use from the base dataset

# dataset for transfer learning
TRANSFER_XYZ = DATA_DIR / "A02_propene_grid_static_4e4o.xyz"
TRANSFER_N_GEOMETRIES = '3731' # number of geometries to use from the transfer dataset

OUTPUT_DIR = ROOT_PATH / "../outputs"
RESULTS_CSV = OUTPUT_DIR / "results" / "repeated_runs_results.csv"

base_atoms_list = ase.io.read(BASE_XYZ, index=f":{BASE_N_GEOMETRIES}")
transfer_atoms_list = ase.io.read(TRANSFER_XYZ, index=f":{TRANSFER_N_GEOMETRIES}")

print("base_atoms_list length:", len(base_atoms_list))
print("transfer_atoms_list length:", len(transfer_atoms_list))
# Out:
# base_atoms_list length: 3731
# transfer_atoms_list length: 3731

# %% [markdown]
# ## 0.2. Split into test, train, valid sets

# %%
# get bond lengths and dihedrals
# tested on propene only

desc_matrix = []
bond_lengths = []
dihedrals = []

for atom in base_atoms_list:
    bond_length = descriptors.get_descriptor("bond_lengths",atom)[0]
    dihedral = descriptors.get_descriptor("dihedral",atom)[0]
    
    bond_lengths.append(bond_length)
    dihedrals.append(dihedral)
    desc_matrix.append([bond_length, dihedral])

desc_matrix = np.asarray(desc_matrix)

# extract test set
# the same test set is removed from both base and transfer datasets

TEST_SET_FRACTION = 0.1
TEST_SET_SIZE = int(np.floor(int(BASE_N_GEOMETRIES) * TEST_SET_FRACTION))

test_set_idx = selectors.get_selector("uniform_grid", desc_matrix, TEST_SET_SIZE)
base_test_set = [base_atoms_list[i] for i in test_set_idx]
transfer_test_set = [transfer_atoms_list[i] for i in test_set_idx]
print("Test set size:", len(base_test_set))

# remaining geometries are for training and validation
train_valid_set_idx = np.setdiff1d(np.arange(len(transfer_atoms_list)), test_set_idx)
base_train_valid_set = [base_atoms_list[i] for i in train_valid_set_idx]
transfer_train_valid_set = [transfer_atoms_list[i] for i in train_valid_set_idx]

# split remaining geometries into train and valid sets
# the same for both base and transfer datasets

SEED = 42 # set as int to get the same split every time
VALID_SET_FRACTION = 0.2 # as a fraction of the total dataset

train_set_idx, valid_set_idx = train_test_split(
    train_valid_set_idx, test_size=VALID_SET_FRACTION/(1-TEST_SET_FRACTION), random_state=SEED, shuffle=True
)

base_train_set = [base_atoms_list[i] for i in train_set_idx]
print("\nBase train set size:", len(base_train_set))
base_valid_set = [base_atoms_list[i] for i in valid_set_idx]
print("Base valid set size:", len(base_valid_set))

transfer_train_set = [transfer_atoms_list[i] for i in train_set_idx]
print("\nFull high-fidelity train set size:", len(transfer_train_set))
transfer_valid_set = [transfer_atoms_list[i] for i in valid_set_idx]
print("Full high-fidelity valid set size:", len(transfer_valid_set))
# Out:
# Test set size: 361
#
# Base train set size: 2621
# Base valid set size: 749
#
# Full high-fidelity train set size: 2621
# Full high-fidelity valid set size: 749

# %%
# visualise
plt.figure(figsize=(6, 10))  

plt.scatter([bond_lengths[i] for i in train_set_idx],
            [dihedrals[i] for i in train_set_idx], 
            color='blue', marker='o', s=10, label='Train')

plt.scatter([bond_lengths[i] for i in test_set_idx], 
            [dihedrals[i] for i in test_set_idx], 
            color='red', marker='o', s=10, label='Test')

plt.scatter([bond_lengths[i] for i in valid_set_idx], 
            [dihedrals[i] for i in valid_set_idx], 
            color='green', marker='o', s=10, label='Valid')

plt.title("Test, train, valid sets")
plt.xlabel("Bond length")
plt.ylabel("Dihedral angle")
plt.legend()

plt.show()

# %% [markdown]
# ## 0.3. Train base model

# %%
base_train_loader = data_builder.load(
    base_train_set, batch_size=BATCH_SIZE, shuffle=True
)
base_valid_loader = data_builder.load(
    base_valid_set, batch_size=BATCH_SIZE, shuffle=False
)
base_test_loader = data_builder.load(
    base_test_set, batch_size=BATCH_SIZE, shuffle=False
)
torch.manual_seed(SEED)

base_model = initialise_autoencoder(data_builder.get_metadata(), preset="lightweight")
base_optimizer = torch.optim.Adam(base_model.parameters(), lr=BASE_LR)

base_model, base_history = trainer.train_model(
    base_model, base_train_loader, base_valid_loader, base_optimizer, loss_fn
)

tester.run_test(base_model, base_test_loader)
base_energy_mae = tester.get_energy_mae()
base_encoder = base_model.perm_encoder
{"best_epoch": base_history["best_epoch"], "test_energy_mae_ev": base_energy_mae}
# Out:
# /home/lim_yt/micromamba/envs/xmace311/lib/python3.11/ast.py:418: UserWarning: The TorchScript type system doesn't support instance-level annotations on empty non-base types in `__init__`. Instead, either 1) use a type annotation in the class body, or 2) wrap the type in `torch.jit.Attribute`.
#   return visitor(node)
# /home/lim_yt/micromamba/envs/xmace311/lib/python3.11/ast.py:418: UserWarning: The TorchScript type system doesn't support instance-level annotations on empty non-base types in `__init__`. Instead, either 1) use a type annotation in the class body, or 2) wrap the type in `torch.jit.Attribute`.
#   return visitor(node)
# /home/lim_yt/micromamba/envs/xmace311/lib/python3.11/ast.py:418: UserWarning: The TorchScript type system doesn't support instance-level annotations on empty non-base types in `__init__`. Instead, either 1) use a type annotation in the class body, or 2) wrap the type in `torch.jit.Attribute`.
#   return visitor(node)
# /home/lim_yt/micromamba/envs/xmace311/lib/python3.11/ast.py:418: UserWarning: The TorchScript type system doesn't support instance-level annotations on empty non-base types in `__init__`. Instead, either 1) use a type annotation in the class body, or 2) wrap the type in `torch.jit.Attribute`.
#   return visitor(node)
# /home/lim_yt/micromamba/envs/xmace311/lib/python3.11/ast.py:418: UserWarning: The TorchScript type system doesn't support instance-level annotations on empty non-base types in `__init__`. Instead, either 1) use a type annotation in the class body, or 2) wrap the type in `torch.jit.Attribute`.
#   return visitor(node)
# /home/lim_yt/micromamba/envs/xmace311/lib/python3.11/ast.py:418: UserWarning: The TorchScript type system doesn't support instance-level annotations on empty non-base types in `__init__`. Instead, either 1) use a type annotation in the class body, or 2) wrap the type in `torch.jit.Attribute`.
#   return visitor(node)
# /home/lim_yt/micromamba/envs/xmace311/lib/python3.11/ast.py:418: UserWarning: The TorchScript type system doesn't support instance-level annotations on empty non-base types in `__init__`. Instead, either 1) use a type annotation in the class body, or 2) wrap the type in `torch.jit.Attribute`.
#   return visitor(node)
# /home/lim_yt/micromamba/envs/xmace311/lib/python3.11/ast.py:418: UserWarning: The TorchScript type system doesn't support instance-level annotations on empty non-base types in `__init__`. Instead, either 1) use a type annotation in the class body, or 2) wrap the type in `torch.jit.Attribute`.
#   return visitor(node)
# Epoch 001 | train_loss=112.202106 | valid_loss=131.505759
# Epoch 002 | train_loss=100.455847 | valid_loss=124.357864
# Epoch 003 | train_loss=76.450234 | valid_loss=54.080552
# Epoch 004 | train_loss=41.250764 | valid_loss=35.191094
# Epoch 005 | train_loss=30.699862 | valid_loss=28.692574
# Epoch 006 | train_loss=28.165526 | valid_loss=27.144892
# Epoch 007 | train_loss=26.770702 | valid_loss=26.186961
# Epoch 008 | train_loss=25.932211 | valid_loss=24.645659
# Epoch 009 | train_loss=25.173279 | valid_loss=24.603856
# Epoch 010 | train_loss=24.889473 | valid_loss=23.767618
# {'best_epoch': 10, 'test_energy_mae_ev': 1.416432499885559}

# %%
# save model
base_model_filename = "base_model_propene_500_geometries_for_pca_testing.pt"
base_model_save_path = OUTPUT_DIR / "base_models" / base_model_filename
torch.save(base_model, base_model_save_path)
print(f"Base model saved to {base_model_save_path}")
# Out:
# Base model saved to /home/lim_yt/X-MACE-sampling/notebooks/../outputs/base_models/base_model_propene_500_geometries_for_pca_testing.pt

# %% [markdown]
# ## 1. Choose descriptor

# %%
# this will overwrite the base model from the previous section
# run this to load the base model from file instead of using previous section

base_model_filename = "base_propene_3731_geom_2e2o_50_epoch.pt"
base_model_save_path = OUTPUT_DIR / "base_models" / base_model_filename
base_model = torch.load(base_model_save_path, weights_only=False)

base_model.eval()

base_encoder = base_model.perm_encoder

# %%
DESCRIPTOR_TYPE = ["bond_lengths", "bond_angles", "dihedral", "energies", "encoded_energies", "soap", "acsf", "mbtr", "latent_space"]
DESCRIPTOR = DESCRIPTOR_TYPE[3]  # choose the descriptor type to use

# matrix of descriptors for each geometry
# sampling is done on base dataset, out of the training pool only
# ie test and valid sets are already removed
desc_matrix = []
if DESCRIPTOR == "latent_space":
    base_train_loader_unshuffle = data_builder.load(
        base_train_set, batch_size=BATCH_SIZE, shuffle=False
    )
    latent_space = extract_latent_space(
        base_model, base_train_loader_unshuffle, device=DEVICE
    )
    desc_matrix = latent_space
else:
    for atom in base_train_set:
        desc_matrix.append(descriptors.get_descriptor(DESCRIPTOR,atom,base_encoder))
    desc_matrix = np.asarray(desc_matrix)

# n*m, where n is the number of geometries and m is the dimension of the descriptor
# eg if we use bond_lengths and propene, m=2 because there's 2 CC bonds in propene
print("desc_matrix shape:", desc_matrix.shape)
print("desc_matrix unique shape:", np.unique(desc_matrix, axis=0).shape)
print("desc_matrix:\n", desc_matrix)
# Out:
# desc_matrix shape: (2621, 3)
# desc_matrix unique shape: (2621, 3)
# desc_matrix:
#  [[-3182.42066727 -3177.5975579  -3176.00304414]
#  [-3181.506713   -3172.64454682 -3164.39903964]
#  [-3183.65452132 -3177.19701174 -3173.34947139]
#  ...
#  [-3181.11625138 -3178.35955563 -3178.16638744]
#  [-3183.39478864 -3175.71783072 -3165.72083817]
#  [-3184.03173916 -3176.23632191 -3171.42583047]]

# %%
# optional dimensionality reduction using PCA

PCA_DIMENSIONS = 3

from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

desc_matrix_scaled = StandardScaler().fit_transform(desc_matrix)

pca = PCA(n_components=PCA_DIMENSIONS)
desc_matrix = pca.fit_transform(desc_matrix_scaled)

print("desc_matrix shape:", desc_matrix.shape)
print("desc_matrix unique shape:", np.unique(desc_matrix, axis=0).shape)
print("desc_matrix:\n", desc_matrix)
# Out:
# desc_matrix shape: (500, 3)
# desc_matrix unique shape: (500, 3)
# desc_matrix:
#  [[ 25.66290073  -7.5435525    3.57461524]
#  [-17.68889132  -1.97186744 -11.88806588]
#  [ -9.68128667   8.30790249  11.93837659]
#  ...
#  [ -4.73528134  13.40840203  -1.75137886]
#  [ -0.93051678  -9.05129291  -4.19616038]
#  [ -3.10642808 -11.28432425  -3.91061191]]

# %% [markdown]
# ## 2. Choose selector

# %%
SELECTOR_TYPE = ["random_sampling", "farthest_point_sampling", "k_means_clustering", "k_means_clustering_weighted", "birch", "birch_weighted", "dbscan", "dbscan_weighted"]
SELECTOR = SELECTOR_TYPE[3]  # choose the selector type to use

# number of samples to select from the transfer dataset
N_SAMPLES = 100

# select samples based on the descriptor matrix
sampled_idx = selectors.get_selector(SELECTOR, desc_matrix, N_SAMPLES, n_clusters=25)

# sample atoms out of transfer dataset
sampled_atoms = [transfer_train_set[i] for i in sampled_idx]

print("sampled indices:\n", sampled_idx)
print("number sampled:", len(sampled_idx))
# Out:
# n clusters: 25
# n clusters with samples: 25
# labels: [13  5 14 ... 23 15 24]
# allocation: [2 9 2 3 5 2 4 7 2 2 2 2 2 8 7 3 4 4 4 3 2 3 8 5 5]
# sampled indices:
#  [2577  164 2607 1527 2122 1137  755 2537 2203  259  548 2182 1368 1410
#   148  294 1305  157 1595  857 1695  274  680  530 2010 2162 1778 1280
#  2574 1599  576  825 2005 2343 2007 2003 2118 1303 2202 1372   57 1680
#  1788 2605 1483 1954  874 1853 2195 1471 1367  228 1899 2167  539 2329
#  1333 2099 2046 1265 1848  653  262 1693 1183 2575 2225 1041 2279 1623
#   133   63 1486  116  721   48 2236  515 2540 1923 1161  166  491 2200
#  1435 1519  231 1613  243  725   25 2033  678 1160  181 2496 1543 2103
#  2073  785]
# number sampled: 100

# %% [markdown]
# ## 3. Repeated runs of training transfer model

# %%
results = []

# %%
N_REPEATS = 25
import time

# load train, valid, test sets
full_valid_loader = data_builder.load(
    transfer_valid_set, batch_size=BATCH_SIZE, shuffle=False
)
full_test_loader = data_builder.load(
    transfer_test_set, batch_size=BATCH_SIZE, shuffle=False
)

for i in range(N_REPEATS):
    start = time.time()
    
    SEED = 42
    torch.manual_seed(SEED)

    # select samples based on the descriptor matrix
    sampled_idx = selectors.get_selector("random_sampling", desc_matrix, 100)

    # sample atoms out of transfer dataset
    sampled_atoms = [transfer_train_set[j] for j in sampled_idx]

    transfer_train_loader = data_builder.load(
        sampled_atoms, batch_size=BATCH_SIZE, shuffle=True
    )

    # do the training
    transfer_model = NaiveStrategy().apply(base_model)
    transfer_optimizer = torch.optim.Adam(transfer_model.parameters(), lr=TRANSFER_LR)

    transfer_model, transfer_history = trainer.train_model(
        transfer_model, transfer_train_loader, full_valid_loader, transfer_optimizer, loss_fn
    )

    # do the testing
    tester.run_test(transfer_model, full_test_loader)
    transfer_best_epoch = transfer_history["best_epoch"]
    transfer_energy_mae = tester.get_energy_mae()
    
    results.append({'seed': SEED, 'best_epoch': transfer_best_epoch, 'energy_mae': transfer_energy_mae})
    results_df = pd.DataFrame(results)
    results_df.to_csv(RESULTS_CSV, index=False)

    print(f"seed: {SEED}, best_epoch {transfer_best_epoch}, energy_mae: {transfer_energy_mae}\n")
    print(f"duration: {time.time() - start}\n")
# Out:
# Epoch 001 | train_loss=11.082422 | valid_loss=8.963839
# Epoch 002 | train_loss=8.092956 | valid_loss=6.629673
# Epoch 003 | train_loss=6.592157 | valid_loss=5.778182
# Epoch 004 | train_loss=5.733639 | valid_loss=5.401194
# Epoch 005 | train_loss=5.258124 | valid_loss=5.450867
# Epoch 006 | train_loss=5.166697 | valid_loss=5.193412
# Epoch 007 | train_loss=5.316008 | valid_loss=5.204930
# Epoch 008 | train_loss=5.059442 | valid_loss=5.385014
# Epoch 009 | train_loss=5.228647 | valid_loss=5.060064
# Epoch 010 | train_loss=5.031683 | valid_loss=4.871565
# Epoch 011 | train_loss=4.857444 | valid_loss=4.860294
# Epoch 012 | train_loss=4.875480 | valid_loss=4.853017
# Epoch 013 | train_loss=5.397897 | valid_loss=5.096072
# Epoch 014 | train_loss=4.901889 | valid_loss=5.170783
# Epoch 015 | train_loss=4.945941 | valid_loss=5.279799
# Epoch 016 | train_loss=5.173462 | valid_loss=4.893108
# Epoch 017 | train_loss=4.897856 | valid_loss=4.784774
# Epoch 018 | train_loss=4.805302 | valid_loss=4.980720
# Epoch 019 | train_loss=4.901403 | valid_loss=4.975351
# Epoch 020 | train_loss=5.004397 | valid_loss=4.959936
# Epoch 021 | train_loss=4.905924 | valid_loss=4.962653
# Epoch 022 | train_loss=4.970879 | valid_loss=5.123170
# Epoch 023 | train_loss=4.950865 | valid_loss=4.788832
# Epoch 024 | train_loss=4.872817 | valid_loss=4.772755
# Epoch 025 | train_loss=4.796391 | valid_loss=4.792262
# Epoch 026 | train_loss=4.655460 | valid_loss=4.746918
# Epoch 027 | train_loss=4.627660 | valid_loss=4.756630
# Epoch 028 | train_loss=4.763197 | valid_loss=4.670181
# Epoch 029 | train_loss=4.622411 | valid_loss=4.653439
# Epoch 030 | train_loss=4.738329 | valid_loss=4.808627
# Epoch 031 | train_loss=4.811489 | valid_loss=4.671473
# Epoch 032 | train_loss=4.713033 | valid_loss=4.676985
# Epoch 033 | train_loss=4.648071 | valid_loss=4.625318
# Epoch 034 | train_loss=4.645453 | valid_loss=4.944260
# Epoch 035 | train_loss=4.940564 | valid_loss=4.829522
# Epoch 036 | train_loss=4.959312 | valid_loss=4.683194
# Epoch 037 | train_loss=4.903802 | valid_loss=4.874620
# Epoch 038 | train_loss=4.795600 | valid_loss=4.733063
# Epoch 039 | train_loss=4.738366 | valid_loss=4.731880
# Epoch 040 | train_loss=5.166533 | valid_loss=4.740696
# Epoch 041 | train_loss=4.923688 | valid_loss=4.835789
# Epoch 042 | train_loss=4.942331 | valid_loss=4.730004
# Epoch 043 | train_loss=4.805985 | valid_loss=4.799385
# Epoch 044 | train_loss=4.662603 | valid_loss=4.655455
# Epoch 045 | train_loss=4.603365 | valid_loss=4.636363
# Epoch 046 | train_loss=4.700989 | valid_loss=4.618513
# Epoch 047 | train_loss=4.466250 | valid_loss=4.586729
# Epoch 048 | train_loss=5.107594 | valid_loss=4.600361
# Epoch 049 | train_loss=4.634597 | valid_loss=4.768532
# Epoch 050 | train_loss=4.714715 | valid_loss=4.690092
# seed: 42, best_epoch 47, energy_mae: 0.6885771155357361
#
# duration: 5709.878512144089
#
# Epoch 001 | train_loss=11.008620 | valid_loss=8.572817
# Epoch 002 | train_loss=8.114885 | valid_loss=6.922073
# Epoch 003 | train_loss=6.592409 | valid_loss=5.760237
# Epoch 004 | train_loss=6.053674 | valid_loss=5.390341
# Epoch 005 | train_loss=5.863000 | valid_loss=5.245549
# Epoch 006 | train_loss=6.773922 | valid_loss=4.980247
# Epoch 007 | train_loss=5.358928 | valid_loss=4.994215
# Epoch 008 | train_loss=5.228980 | valid_loss=4.925545
# Epoch 009 | train_loss=5.403881 | valid_loss=5.160430
# Epoch 010 | train_loss=5.388429 | valid_loss=4.807397
# Epoch 011 | train_loss=5.153155 | valid_loss=4.793786
# Epoch 012 | train_loss=5.273235 | valid_loss=4.953569
# Epoch 013 | train_loss=5.095237 | valid_loss=4.782718
# Epoch 014 | train_loss=5.168495 | valid_loss=4.904806
# Epoch 015 | train_loss=5.144456 | valid_loss=4.711826
# Epoch 016 | train_loss=5.135793 | valid_loss=4.698341
# Epoch 017 | train_loss=5.203858 | valid_loss=4.672099
# Epoch 018 | train_loss=4.965910 | valid_loss=4.679053
# Epoch 019 | train_loss=5.049774 | valid_loss=4.804725
# Epoch 020 | train_loss=5.414980 | valid_loss=4.636154
# Epoch 021 | train_loss=4.953554 | valid_loss=4.697947
# Epoch 022 | train_loss=5.081644 | valid_loss=4.591205
# Epoch 023 | train_loss=4.968374 | valid_loss=4.629490
# Epoch 024 | train_loss=5.057956 | valid_loss=4.693861
# Epoch 025 | train_loss=5.025327 | valid_loss=4.550331
# Epoch 026 | train_loss=5.091043 | valid_loss=4.581902
# Epoch 027 | train_loss=4.918292 | valid_loss=4.646885
# Epoch 028 | train_loss=5.014841 | valid_loss=4.617188
# Epoch 029 | train_loss=5.313309 | valid_loss=4.610147
# Epoch 030 | train_loss=4.910323 | valid_loss=4.605381
# Epoch 031 | train_loss=4.840556 | valid_loss=4.594721
# Epoch 032 | train_loss=4.889279 | valid_loss=4.543621
# Epoch 033 | train_loss=4.844991 | valid_loss=4.622667
# Epoch 034 | train_loss=4.841449 | valid_loss=4.538633
# Epoch 035 | train_loss=5.155729 | valid_loss=4.769745
# Epoch 036 | train_loss=4.982225 | valid_loss=4.676271
# Epoch 037 | train_loss=5.292167 | valid_loss=4.566752
# Epoch 038 | train_loss=4.844636 | valid_loss=4.632197
# Epoch 039 | train_loss=4.905728 | valid_loss=4.639725
# Epoch 040 | train_loss=4.960563 | valid_loss=4.746630
# Epoch 041 | train_loss=5.171731 | valid_loss=4.636964
# Epoch 042 | train_loss=4.882941 | valid_loss=4.606029
# Epoch 043 | train_loss=4.832935 | valid_loss=4.645259
# Epoch 044 | train_loss=4.868815 | valid_loss=4.584292
# Epoch 045 | train_loss=4.902769 | valid_loss=4.591606
# Epoch 046 | train_loss=4.800275 | valid_loss=4.506074
# Epoch 047 | train_loss=4.839926 | valid_loss=4.554302
# Epoch 048 | train_loss=4.901222 | valid_loss=4.700017
# Epoch 049 | train_loss=4.948257 | valid_loss=4.607470
# Epoch 050 | train_loss=4.921462 | valid_loss=4.771047
# seed: 42, best_epoch 46, energy_mae: 0.6829532980918884
#
# duration: 5083.817786216736
#
# Epoch 001 | train_loss=11.206788 | valid_loss=8.224650
# Epoch 002 | train_loss=7.875571 | valid_loss=6.658298
# Epoch 003 | train_loss=6.601362 | valid_loss=5.709575
# Epoch 004 | train_loss=6.039934 | valid_loss=5.439130
# Epoch 005 | train_loss=5.974045 | valid_loss=5.246071
# Epoch 006 | train_loss=5.523730 | valid_loss=5.148277
# Epoch 007 | train_loss=5.484607 | valid_loss=5.253109
# Epoch 008 | train_loss=5.328389 | valid_loss=4.931903
# Epoch 009 | train_loss=5.254338 | valid_loss=4.858041
# Epoch 010 | train_loss=5.098499 | valid_loss=4.797239
# Epoch 011 | train_loss=5.190878 | valid_loss=4.779165
# Epoch 012 | train_loss=5.569574 | valid_loss=4.818650
# Epoch 013 | train_loss=5.669803 | valid_loss=4.859232
# Epoch 014 | train_loss=5.309053 | valid_loss=4.765967
# Epoch 015 | train_loss=5.042071 | valid_loss=4.825057
# Epoch 016 | train_loss=4.981626 | valid_loss=4.807254
# Epoch 017 | train_loss=5.111868 | valid_loss=4.765629
# Epoch 018 | train_loss=4.830723 | valid_loss=4.757858
# Epoch 019 | train_loss=5.121116 | valid_loss=4.824016
# Epoch 020 | train_loss=5.194115 | valid_loss=4.776448
# Epoch 021 | train_loss=5.135724 | valid_loss=5.096541
# Epoch 022 | train_loss=5.024616 | valid_loss=4.732112
# Epoch 023 | train_loss=5.108901 | valid_loss=4.761687
# Epoch 024 | train_loss=4.975140 | valid_loss=4.667411
# Epoch 025 | train_loss=4.907857 | valid_loss=4.824768
# Epoch 026 | train_loss=5.143362 | valid_loss=4.726497
# Epoch 027 | train_loss=5.028001 | valid_loss=4.836218
# Epoch 028 | train_loss=5.055758 | valid_loss=4.762030
# Epoch 029 | train_loss=4.917652 | valid_loss=4.649601
# Epoch 030 | train_loss=4.941895 | valid_loss=4.904964
# Epoch 031 | train_loss=5.033619 | valid_loss=4.678672
# Epoch 032 | train_loss=5.689390 | valid_loss=4.738509
# Epoch 033 | train_loss=4.858581 | valid_loss=4.803896
# Epoch 034 | train_loss=5.155012 | valid_loss=4.812461
# Epoch 035 | train_loss=4.902169 | valid_loss=4.680673
# Epoch 036 | train_loss=4.748415 | valid_loss=4.618659
# Epoch 037 | train_loss=4.832452 | valid_loss=4.636498
# Epoch 038 | train_loss=4.820254 | valid_loss=4.696209
# Epoch 039 | train_loss=4.844085 | valid_loss=4.632995
# Epoch 040 | train_loss=4.878280 | valid_loss=4.664448
# Epoch 041 | train_loss=5.000270 | valid_loss=4.542903
# Epoch 042 | train_loss=4.772471 | valid_loss=4.586986
# Epoch 043 | train_loss=4.840428 | valid_loss=4.563568
# Epoch 044 | train_loss=5.136083 | valid_loss=4.657709
# Epoch 045 | train_loss=4.822874 | valid_loss=4.837937
# Epoch 046 | train_loss=4.916813 | valid_loss=4.800035
# Epoch 047 | train_loss=4.924277 | valid_loss=4.921083
# Epoch 048 | train_loss=4.875834 | valid_loss=4.783908
# Epoch 049 | train_loss=4.986375 | valid_loss=4.672231
# Epoch 050 | train_loss=4.966784 | valid_loss=4.591813
# seed: 42, best_epoch 41, energy_mae: 0.6807814836502075
#
# duration: 5139.087183237076
#
# Epoch 001 | train_loss=10.600254 | valid_loss=8.258515
# Epoch 002 | train_loss=7.685372 | valid_loss=6.619700
# Epoch 003 | train_loss=6.164278 | valid_loss=5.642085
# Epoch 004 | train_loss=6.046995 | valid_loss=5.498407
# Epoch 005 | train_loss=5.701903 | valid_loss=5.243294
# Epoch 006 | train_loss=5.503757 | valid_loss=5.374964
# Epoch 007 | train_loss=5.447743 | valid_loss=5.034635
# Epoch 008 | train_loss=5.239897 | valid_loss=4.941718
# Epoch 009 | train_loss=5.563836 | valid_loss=4.937043
# Epoch 010 | train_loss=5.133902 | valid_loss=4.902576
# Epoch 011 | train_loss=4.965698 | valid_loss=4.795256
# Epoch 012 | train_loss=5.013502 | valid_loss=4.722296
# Epoch 013 | train_loss=4.765854 | valid_loss=4.822552
# Epoch 014 | train_loss=4.850403 | valid_loss=4.830045
# Epoch 015 | train_loss=5.123078 | valid_loss=4.874302
# Epoch 016 | train_loss=4.945424 | valid_loss=4.943694
# Epoch 017 | train_loss=5.054895 | valid_loss=4.896043
# Epoch 018 | train_loss=4.942431 | valid_loss=4.765147
# Epoch 019 | train_loss=4.935789 | valid_loss=4.859754
# Epoch 020 | train_loss=4.790938 | valid_loss=4.697680
# Epoch 021 | train_loss=5.055496 | valid_loss=4.745479
# Epoch 022 | train_loss=4.659095 | valid_loss=4.709129
# Epoch 023 | train_loss=4.647631 | valid_loss=4.799424
# Epoch 024 | train_loss=4.629221 | valid_loss=4.690322
# Epoch 025 | train_loss=5.026530 | valid_loss=4.759006
# Epoch 026 | train_loss=4.619935 | valid_loss=4.598362
# Epoch 027 | train_loss=4.631793 | valid_loss=4.649120
# Epoch 028 | train_loss=4.815732 | valid_loss=4.591775
# Epoch 029 | train_loss=4.638817 | valid_loss=4.777456
# Epoch 030 | train_loss=4.538919 | valid_loss=4.665255
# Epoch 031 | train_loss=4.780801 | valid_loss=4.788487
# Epoch 032 | train_loss=4.769913 | valid_loss=5.149714
# Epoch 033 | train_loss=4.829081 | valid_loss=4.847788
# Epoch 034 | train_loss=5.213903 | valid_loss=5.054968
# Epoch 035 | train_loss=5.201081 | valid_loss=4.895080
# Epoch 036 | train_loss=4.520074 | valid_loss=4.782568
# Epoch 037 | train_loss=4.758430 | valid_loss=4.626258
# Epoch 038 | train_loss=4.566705 | valid_loss=4.707046
# Epoch 039 | train_loss=4.626542 | valid_loss=4.889063
# Epoch 040 | train_loss=4.487872 | valid_loss=4.549102
# Epoch 041 | train_loss=4.801229 | valid_loss=4.786739
# Epoch 042 | train_loss=4.708301 | valid_loss=4.676917
# Epoch 043 | train_loss=4.807849 | valid_loss=4.665749
# Epoch 044 | train_loss=4.751150 | valid_loss=4.530954
# Epoch 045 | train_loss=4.552373 | valid_loss=4.675065
# Epoch 046 | train_loss=4.584458 | valid_loss=4.538805
# Epoch 047 | train_loss=4.414500 | valid_loss=4.539902
# Epoch 048 | train_loss=4.449722 | valid_loss=4.586726
# Epoch 049 | train_loss=4.391077 | valid_loss=4.887668
# Epoch 050 | train_loss=4.593714 | valid_loss=4.692653
# seed: 42, best_epoch 44, energy_mae: 0.6793085336685181
#
# duration: 5113.894431114197
#
# Epoch 001 | train_loss=10.961851 | valid_loss=8.323399
# Epoch 002 | train_loss=7.377042 | valid_loss=6.563175
# Epoch 003 | train_loss=6.275235 | valid_loss=5.733307
# Epoch 004 | train_loss=5.362827 | valid_loss=5.484169
# Epoch 005 | train_loss=4.965696 | valid_loss=5.287985
# Epoch 006 | train_loss=5.198871 | valid_loss=5.127021
# Epoch 007 | train_loss=4.870695 | valid_loss=5.051178
# Epoch 008 | train_loss=4.766454 | valid_loss=4.941791
# Epoch 009 | train_loss=4.770438 | valid_loss=5.126000
# Epoch 010 | train_loss=4.967716 | valid_loss=4.896462
# Epoch 011 | train_loss=4.873263 | valid_loss=4.904430
# Epoch 012 | train_loss=4.873933 | valid_loss=4.868804
# Epoch 013 | train_loss=4.724455 | valid_loss=4.925365
# Epoch 014 | train_loss=4.656794 | valid_loss=4.817674
# Epoch 015 | train_loss=4.695845 | valid_loss=5.011995
# Epoch 016 | train_loss=4.816206 | valid_loss=5.034494
# Epoch 017 | train_loss=4.647070 | valid_loss=4.901086
# Epoch 018 | train_loss=4.654564 | valid_loss=4.778541
# Epoch 019 | train_loss=4.792308 | valid_loss=4.701803
# Epoch 020 | train_loss=4.522666 | valid_loss=4.707859
# Epoch 021 | train_loss=4.685635 | valid_loss=4.700896
# Epoch 022 | train_loss=4.533608 | valid_loss=4.728167
# Epoch 023 | train_loss=4.783916 | valid_loss=4.794874
# Epoch 024 | train_loss=4.583516 | valid_loss=4.705155
# Epoch 025 | train_loss=4.526259 | valid_loss=4.699272
# Epoch 026 | train_loss=4.580472 | valid_loss=4.632895
# Epoch 027 | train_loss=4.842048 | valid_loss=4.635631
# Epoch 028 | train_loss=4.381086 | valid_loss=4.640789
# Epoch 029 | train_loss=4.548319 | valid_loss=4.623248
# Epoch 030 | train_loss=4.447982 | valid_loss=4.636857
# Epoch 031 | train_loss=4.557846 | valid_loss=4.722096
# Epoch 032 | train_loss=4.813977 | valid_loss=4.630629
# Epoch 033 | train_loss=4.584817 | valid_loss=4.598084
# Epoch 034 | train_loss=4.403512 | valid_loss=4.642180
# Epoch 035 | train_loss=4.504805 | valid_loss=4.699293
# Epoch 036 | train_loss=4.467698 | valid_loss=4.673702
# Epoch 037 | train_loss=4.383251 | valid_loss=4.721211
# Epoch 038 | train_loss=4.551904 | valid_loss=4.602687
# Epoch 039 | train_loss=4.453104 | valid_loss=4.626219
# Epoch 040 | train_loss=4.342160 | valid_loss=4.627956
# Epoch 041 | train_loss=4.544056 | valid_loss=4.676883
# Epoch 042 | train_loss=4.418002 | valid_loss=4.646248
# Epoch 043 | train_loss=4.426795 | valid_loss=4.566709
# Epoch 044 | train_loss=4.420088 | valid_loss=4.581908
# Epoch 045 | train_loss=4.304279 | valid_loss=4.546453
# Epoch 046 | train_loss=4.559678 | valid_loss=4.618988
# Epoch 047 | train_loss=4.489957 | valid_loss=4.710622
# Epoch 048 | train_loss=4.393195 | valid_loss=4.568655
# Epoch 049 | train_loss=4.557760 | valid_loss=4.557129
# Epoch 050 | train_loss=4.468155 | valid_loss=4.763668
# seed: 42, best_epoch 45, energy_mae: 0.6776561737060547
#
# duration: 5041.8111391067505
#
# Epoch 001 | train_loss=11.049129 | valid_loss=8.612186
# Epoch 002 | train_loss=8.402996 | valid_loss=7.259679
# Epoch 003 | train_loss=6.809968 | valid_loss=5.861185
# Epoch 004 | train_loss=6.348718 | valid_loss=5.969736
# Epoch 005 | train_loss=5.955207 | valid_loss=5.576148
# Epoch 006 | train_loss=5.938000 | valid_loss=5.497178
# Epoch 007 | train_loss=5.837781 | valid_loss=5.210724
# Epoch 008 | train_loss=5.661010 | valid_loss=5.128253
# Epoch 009 | train_loss=5.597014 | valid_loss=5.092728
# Epoch 010 | train_loss=5.431551 | valid_loss=4.866998
# Epoch 011 | train_loss=5.681908 | valid_loss=4.818308
# Epoch 012 | train_loss=5.422041 | valid_loss=4.894524
# Epoch 013 | train_loss=5.560970 | valid_loss=4.886301
# Epoch 014 | train_loss=5.441324 | valid_loss=4.801052
# Epoch 015 | train_loss=5.715584 | valid_loss=4.845839
# Epoch 016 | train_loss=5.439823 | valid_loss=4.831739
# Epoch 017 | train_loss=5.297882 | valid_loss=4.865585
# Epoch 018 | train_loss=5.313489 | valid_loss=4.818178
# Epoch 019 | train_loss=5.511161 | valid_loss=4.895980
# Epoch 020 | train_loss=5.564716 | valid_loss=4.807732
# Epoch 021 | train_loss=5.586987 | valid_loss=4.745403
# Epoch 022 | train_loss=5.332995 | valid_loss=4.787703
# Epoch 023 | train_loss=5.730512 | valid_loss=4.959608
# Epoch 024 | train_loss=5.575777 | valid_loss=5.070091
# Epoch 025 | train_loss=5.507941 | valid_loss=4.776326
# Epoch 026 | train_loss=5.574642 | valid_loss=4.703238
# Epoch 027 | train_loss=5.425969 | valid_loss=4.767670
# Epoch 028 | train_loss=5.366922 | valid_loss=4.658392
# Epoch 029 | train_loss=5.688910 | valid_loss=4.629276
# Epoch 030 | train_loss=5.604556 | valid_loss=4.798845
# Epoch 031 | train_loss=5.377250 | valid_loss=4.688241
# Epoch 032 | train_loss=5.368489 | valid_loss=4.665640
# Epoch 033 | train_loss=5.210095 | valid_loss=4.689470
# Epoch 034 | train_loss=5.136238 | valid_loss=4.677802
# Epoch 035 | train_loss=5.283830 | valid_loss=4.961502
# Epoch 036 | train_loss=5.436578 | valid_loss=4.838582
# Epoch 037 | train_loss=5.820989 | valid_loss=4.678363
# Epoch 038 | train_loss=5.390362 | valid_loss=4.908960
# Epoch 039 | train_loss=5.431002 | valid_loss=4.721969
# Epoch 040 | train_loss=5.299830 | valid_loss=4.866488
# Epoch 041 | train_loss=5.478967 | valid_loss=4.599569
# Epoch 042 | train_loss=5.216547 | valid_loss=4.642745
# Epoch 043 | train_loss=5.271404 | valid_loss=4.606349
# Epoch 044 | train_loss=5.171999 | valid_loss=4.648013
# Epoch 045 | train_loss=5.318471 | valid_loss=4.777863
# Epoch 046 | train_loss=5.108272 | valid_loss=4.578324
# Epoch 047 | train_loss=5.734011 | valid_loss=4.582978
# Epoch 048 | train_loss=5.152580 | valid_loss=4.563172
# Epoch 049 | train_loss=5.280111 | valid_loss=4.731332
# Epoch 050 | train_loss=5.053538 | valid_loss=4.697363
# seed: 42, best_epoch 48, energy_mae: 0.667466938495636
#
# duration: 2356.565680503845
#
# Epoch 001 | train_loss=10.875653 | valid_loss=8.468357
# Epoch 002 | train_loss=7.734293 | valid_loss=6.546457
# Epoch 003 | train_loss=6.220837 | valid_loss=5.972756
# Epoch 004 | train_loss=5.632668 | valid_loss=5.403313
# Epoch 005 | train_loss=5.242776 | valid_loss=5.418415
# Epoch 006 | train_loss=5.759680 | valid_loss=5.153489
# Epoch 007 | train_loss=5.120636 | valid_loss=5.002639
# Epoch 008 | train_loss=5.182622 | valid_loss=4.891387
# Epoch 009 | train_loss=5.180824 | valid_loss=4.919551
# Epoch 010 | train_loss=5.025588 | valid_loss=4.902941
# Epoch 011 | train_loss=5.015458 | valid_loss=4.984152
# Epoch 012 | train_loss=5.149350 | valid_loss=4.808886
# Epoch 013 | train_loss=5.204958 | valid_loss=4.921366
# Epoch 014 | train_loss=4.784800 | valid_loss=4.746271
# Epoch 015 | train_loss=4.972705 | valid_loss=4.720511
# Epoch 016 | train_loss=4.864768 | valid_loss=4.763613
# Epoch 017 | train_loss=5.088590 | valid_loss=5.061976
# Epoch 018 | train_loss=4.857832 | valid_loss=4.844710
# Epoch 019 | train_loss=4.982378 | valid_loss=4.785135
# Epoch 020 | train_loss=4.867331 | valid_loss=4.694443
# Epoch 021 | train_loss=4.590735 | valid_loss=4.741331
# Epoch 022 | train_loss=4.712389 | valid_loss=4.715889
# Epoch 023 | train_loss=4.843218 | valid_loss=4.806755
# Epoch 024 | train_loss=4.783579 | valid_loss=4.730812
# Epoch 025 | train_loss=4.710062 | valid_loss=4.676562
# Epoch 026 | train_loss=4.675005 | valid_loss=4.873920
# Epoch 027 | train_loss=4.753832 | valid_loss=4.648113
# Epoch 028 | train_loss=4.876746 | valid_loss=4.702432
# Epoch 029 | train_loss=4.628802 | valid_loss=4.731644
# Epoch 030 | train_loss=4.720568 | valid_loss=4.631779
# Epoch 031 | train_loss=4.896093 | valid_loss=4.597400
# Epoch 032 | train_loss=4.639759 | valid_loss=4.863193
# Epoch 033 | train_loss=4.889335 | valid_loss=4.646975
# Epoch 034 | train_loss=4.707191 | valid_loss=4.642251
# Epoch 035 | train_loss=5.096888 | valid_loss=4.643331
# Epoch 036 | train_loss=5.104015 | valid_loss=4.776637
# Epoch 037 | train_loss=4.861245 | valid_loss=4.803797
# Epoch 038 | train_loss=4.640805 | valid_loss=4.736767
# Epoch 039 | train_loss=4.509846 | valid_loss=4.661193
# Epoch 040 | train_loss=4.475134 | valid_loss=4.552812
# Epoch 041 | train_loss=4.922354 | valid_loss=4.618521
# Epoch 042 | train_loss=4.507336 | valid_loss=4.624035
# Epoch 043 | train_loss=4.810570 | valid_loss=4.588697
# Epoch 044 | train_loss=4.733271 | valid_loss=4.550622
# Epoch 045 | train_loss=4.852503 | valid_loss=4.748325
# Epoch 046 | train_loss=4.856802 | valid_loss=4.652657
# Epoch 047 | train_loss=4.611163 | valid_loss=4.514070
# Epoch 048 | train_loss=4.648312 | valid_loss=4.512829
# Epoch 049 | train_loss=4.486170 | valid_loss=4.591011
# Epoch 050 | train_loss=4.506931 | valid_loss=4.486407
# seed: 42, best_epoch 50, energy_mae: 0.6798376441001892
#
# duration: 1553.486493587494
#
# Epoch 001 | train_loss=10.484693 | valid_loss=8.478543
# Epoch 002 | train_loss=7.495085 | valid_loss=6.669750
# Epoch 003 | train_loss=6.809318 | valid_loss=6.201089
# Epoch 004 | train_loss=6.203574 | valid_loss=5.390920
# Epoch 005 | train_loss=5.267854 | valid_loss=5.382086
# Epoch 006 | train_loss=5.323155 | valid_loss=5.208266
# Epoch 007 | train_loss=5.278366 | valid_loss=5.122370
# Epoch 008 | train_loss=5.123826 | valid_loss=5.124208
# Epoch 009 | train_loss=5.055513 | valid_loss=4.881778
# Epoch 010 | train_loss=5.142203 | valid_loss=4.974782
# Epoch 011 | train_loss=4.943783 | valid_loss=4.807232
# Epoch 012 | train_loss=4.854505 | valid_loss=4.794224
# Epoch 013 | train_loss=4.820304 | valid_loss=4.879807
# Epoch 014 | train_loss=5.095777 | valid_loss=4.766698
# Epoch 015 | train_loss=4.750084 | valid_loss=4.707090
# Epoch 016 | train_loss=4.768967 | valid_loss=4.765706
# Epoch 017 | train_loss=5.088072 | valid_loss=4.783435
# Epoch 018 | train_loss=4.815664 | valid_loss=4.679181
# Epoch 019 | train_loss=4.774569 | valid_loss=4.671572
# Epoch 020 | train_loss=4.738651 | valid_loss=4.644233
# Epoch 021 | train_loss=4.770901 | valid_loss=4.788150
# Epoch 022 | train_loss=4.841160 | valid_loss=4.671051
# Epoch 023 | train_loss=4.690037 | valid_loss=4.750634
# Epoch 024 | train_loss=4.764384 | valid_loss=4.677588
# Epoch 025 | train_loss=5.105219 | valid_loss=4.792635
# Epoch 026 | train_loss=4.860858 | valid_loss=4.825568
# Epoch 027 | train_loss=4.878140 | valid_loss=4.619934
# Epoch 028 | train_loss=4.600794 | valid_loss=4.624742
# Epoch 029 | train_loss=5.036712 | valid_loss=4.709429
# Epoch 030 | train_loss=4.745494 | valid_loss=4.622025
# Epoch 031 | train_loss=4.790851 | valid_loss=4.732718
# Epoch 032 | train_loss=4.684575 | valid_loss=4.690725
# Epoch 033 | train_loss=4.702440 | valid_loss=4.657190
# Epoch 034 | train_loss=4.906044 | valid_loss=4.596890
# Epoch 035 | train_loss=4.681196 | valid_loss=4.613550
# Epoch 036 | train_loss=4.749108 | valid_loss=4.627112
# Epoch 037 | train_loss=4.713216 | valid_loss=4.653780
# Epoch 038 | train_loss=4.673288 | valid_loss=4.718398
# Epoch 039 | train_loss=4.683484 | valid_loss=4.609788
# Epoch 040 | train_loss=4.622636 | valid_loss=4.563211
# Epoch 041 | train_loss=4.707445 | valid_loss=4.598760
# Epoch 042 | train_loss=4.701900 | valid_loss=4.614849
# Epoch 043 | train_loss=4.580441 | valid_loss=4.552337
# Epoch 044 | train_loss=4.534689 | valid_loss=4.585967
# Epoch 045 | train_loss=4.777445 | valid_loss=4.736428
# Epoch 046 | train_loss=4.751530 | valid_loss=4.724929
# Epoch 047 | train_loss=4.635227 | valid_loss=4.691160
# Epoch 048 | train_loss=4.836043 | valid_loss=4.629188
# Epoch 049 | train_loss=5.039877 | valid_loss=4.688936
# Epoch 050 | train_loss=4.620315 | valid_loss=4.719362
# seed: 42, best_epoch 43, energy_mae: 0.6912800073623657
#
# duration: 1506.502336025238
#
# Epoch 001 | train_loss=11.062913 | valid_loss=8.769705
# Epoch 002 | train_loss=7.280034 | valid_loss=6.541044
# Epoch 003 | train_loss=5.851180 | valid_loss=5.659786
# Epoch 004 | train_loss=5.473864 | valid_loss=5.474902
# Epoch 005 | train_loss=5.294237 | valid_loss=5.277493
# Epoch 006 | train_loss=5.058947 | valid_loss=5.010120
# Epoch 007 | train_loss=4.847463 | valid_loss=5.040851
# Epoch 008 | train_loss=4.819063 | valid_loss=4.940150
# Epoch 009 | train_loss=4.598662 | valid_loss=4.966474
# Epoch 010 | train_loss=5.055214 | valid_loss=4.949765
# Epoch 011 | train_loss=4.637485 | valid_loss=4.881474
# Epoch 012 | train_loss=4.711973 | valid_loss=4.817567
# Epoch 013 | train_loss=4.843873 | valid_loss=4.899525
# Epoch 014 | train_loss=4.696044 | valid_loss=4.813530
# Epoch 015 | train_loss=4.506162 | valid_loss=4.858194
# Epoch 016 | train_loss=4.653413 | valid_loss=5.046125
# Epoch 017 | train_loss=4.679633 | valid_loss=4.858531
# Epoch 018 | train_loss=4.655867 | valid_loss=4.901883
# Epoch 019 | train_loss=4.534788 | valid_loss=4.741056
# Epoch 020 | train_loss=4.613966 | valid_loss=4.767623
# Epoch 021 | train_loss=4.648408 | valid_loss=4.749657
# Epoch 022 | train_loss=4.657343 | valid_loss=4.821449
# Epoch 023 | train_loss=4.997413 | valid_loss=4.782439
# Epoch 024 | train_loss=4.594085 | valid_loss=4.678665
# Epoch 025 | train_loss=4.822435 | valid_loss=4.701491
# Epoch 026 | train_loss=4.584836 | valid_loss=4.648381
# Epoch 027 | train_loss=4.628602 | valid_loss=4.801463
# Epoch 028 | train_loss=4.649999 | valid_loss=4.705772
# Epoch 029 | train_loss=4.505663 | valid_loss=4.684226
# Epoch 030 | train_loss=4.833158 | valid_loss=4.796143
# Epoch 031 | train_loss=4.630809 | valid_loss=4.700639
# Epoch 032 | train_loss=4.516214 | valid_loss=4.649504
# Epoch 033 | train_loss=4.561045 | valid_loss=4.658314
# Epoch 034 | train_loss=4.389645 | valid_loss=4.611561
# Epoch 035 | train_loss=4.620686 | valid_loss=4.712868
# Epoch 036 | train_loss=4.630211 | valid_loss=4.682819
# Epoch 037 | train_loss=4.464933 | valid_loss=4.603880
# Epoch 038 | train_loss=4.341432 | valid_loss=4.604984
# Epoch 039 | train_loss=4.402934 | valid_loss=4.570731
# Epoch 040 | train_loss=4.372439 | valid_loss=4.608427
# Epoch 041 | train_loss=4.333835 | valid_loss=4.583467
# Epoch 042 | train_loss=4.528233 | valid_loss=4.564589
# Epoch 043 | train_loss=4.515463 | valid_loss=4.579851
# Epoch 044 | train_loss=4.442243 | valid_loss=4.560875
# Epoch 045 | train_loss=4.528148 | valid_loss=4.603921
# Epoch 046 | train_loss=4.363767 | valid_loss=4.814755
# Epoch 047 | train_loss=4.917862 | valid_loss=4.649666
# Epoch 048 | train_loss=4.524079 | valid_loss=4.562147
# Epoch 049 | train_loss=4.439792 | valid_loss=4.548886
# Epoch 050 | train_loss=4.505397 | valid_loss=4.685740
# seed: 42, best_epoch 49, energy_mae: 0.6642948985099792
#
# duration: 1549.3677887916565
#
# Epoch 001 | train_loss=9.936742 | valid_loss=8.458219
# Epoch 002 | train_loss=7.323696 | valid_loss=6.593153
# Epoch 003 | train_loss=6.117362 | valid_loss=6.030779
# Epoch 004 | train_loss=5.550275 | valid_loss=5.343918
# Epoch 005 | train_loss=5.239093 | valid_loss=5.114940
# Epoch 006 | train_loss=5.206871 | valid_loss=5.218503
# Epoch 007 | train_loss=5.273265 | valid_loss=5.207121
# Epoch 008 | train_loss=5.175281 | valid_loss=5.035075
# Epoch 009 | train_loss=5.130087 | valid_loss=5.081241
# Epoch 010 | train_loss=5.144843 | valid_loss=4.941967
# Epoch 011 | train_loss=4.977600 | valid_loss=4.913197
# Epoch 012 | train_loss=4.877914 | valid_loss=4.847298
# Epoch 013 | train_loss=4.905587 | valid_loss=4.828186
# Epoch 014 | train_loss=4.688657 | valid_loss=4.760547
# Epoch 015 | train_loss=4.863350 | valid_loss=4.878193
# Epoch 016 | train_loss=4.735580 | valid_loss=4.772786
# Epoch 017 | train_loss=4.946660 | valid_loss=4.737440
# Epoch 018 | train_loss=4.732678 | valid_loss=4.879814
# Epoch 019 | train_loss=4.815889 | valid_loss=4.779481
# Epoch 020 | train_loss=4.816717 | valid_loss=4.773818
# Epoch 021 | train_loss=4.747567 | valid_loss=4.675411
# Epoch 022 | train_loss=4.704701 | valid_loss=4.768548
# Epoch 023 | train_loss=5.052253 | valid_loss=4.731314
# Epoch 024 | train_loss=4.763121 | valid_loss=4.673802
# Epoch 025 | train_loss=4.942140 | valid_loss=4.699993
# Epoch 026 | train_loss=5.051421 | valid_loss=4.736484
# Epoch 027 | train_loss=4.714394 | valid_loss=4.705869
# Epoch 028 | train_loss=4.764979 | valid_loss=4.891779
# Epoch 029 | train_loss=4.784035 | valid_loss=4.693711
# Epoch 030 | train_loss=4.839690 | valid_loss=4.802068
# Epoch 031 | train_loss=4.777109 | valid_loss=4.658200
# Epoch 032 | train_loss=4.871273 | valid_loss=4.881514
# Epoch 033 | train_loss=5.089783 | valid_loss=4.691087
# Epoch 034 | train_loss=4.838309 | valid_loss=4.671764
# Epoch 035 | train_loss=4.770682 | valid_loss=4.687525
# Epoch 036 | train_loss=4.759077 | valid_loss=4.644050
# Epoch 037 | train_loss=4.717892 | valid_loss=4.774302
# Epoch 038 | train_loss=4.581634 | valid_loss=4.682563
# Epoch 039 | train_loss=4.635435 | valid_loss=4.778810
# Epoch 040 | train_loss=4.698371 | valid_loss=4.670232
# Epoch 041 | train_loss=4.905398 | valid_loss=4.600052
# Epoch 042 | train_loss=4.525835 | valid_loss=4.697727
# Epoch 043 | train_loss=4.643939 | valid_loss=4.619185
# Epoch 044 | train_loss=4.575619 | valid_loss=4.638933
# Epoch 045 | train_loss=4.665852 | valid_loss=4.699957
# Epoch 046 | train_loss=4.628242 | valid_loss=4.560651
# Epoch 047 | train_loss=4.573019 | valid_loss=4.651857
# Epoch 048 | train_loss=4.550132 | valid_loss=4.562915
# Epoch 049 | train_loss=4.741786 | valid_loss=4.657331
# Epoch 050 | train_loss=4.582990 | valid_loss=4.590371
# seed: 42, best_epoch 46, energy_mae: 0.6688801646232605
#
# duration: 1533.2265121936798
#
# Epoch 001 | train_loss=10.667249 | valid_loss=8.737168
# Epoch 002 | train_loss=7.522880 | valid_loss=6.759684
# Epoch 003 | train_loss=5.988151 | valid_loss=5.552494
# Epoch 004 | train_loss=5.291256 | valid_loss=5.275739
# Epoch 005 | train_loss=5.042487 | valid_loss=5.276764
# Epoch 006 | train_loss=5.340148 | valid_loss=5.043542
# Epoch 007 | train_loss=5.048618 | valid_loss=5.007533
# Epoch 008 | train_loss=4.794941 | valid_loss=5.032809
# Epoch 009 | train_loss=4.913466 | valid_loss=4.814529
# Epoch 010 | train_loss=4.899930 | valid_loss=4.881205
# Epoch 011 | train_loss=5.190627 | valid_loss=4.860206
# Epoch 012 | train_loss=4.891122 | valid_loss=5.039864
# Epoch 013 | train_loss=4.725762 | valid_loss=4.854527
# Epoch 014 | train_loss=4.934131 | valid_loss=4.805384
# Epoch 015 | train_loss=4.528632 | valid_loss=4.822847
# Epoch 016 | train_loss=4.546810 | valid_loss=4.746371
# Epoch 017 | train_loss=4.842634 | valid_loss=4.761956
# Epoch 018 | train_loss=4.751566 | valid_loss=4.784103
# Epoch 019 | train_loss=4.591204 | valid_loss=4.835615
# Epoch 020 | train_loss=4.920229 | valid_loss=4.743971
# Epoch 021 | train_loss=4.916623 | valid_loss=4.741801
# Epoch 022 | train_loss=4.689890 | valid_loss=4.793443
# Epoch 023 | train_loss=4.649659 | valid_loss=4.679260
# Epoch 024 | train_loss=4.526707 | valid_loss=4.718865
# Epoch 025 | train_loss=4.610283 | valid_loss=5.083002
# Epoch 026 | train_loss=5.135883 | valid_loss=4.682048
# Epoch 027 | train_loss=5.099563 | valid_loss=5.032800
# Epoch 028 | train_loss=4.858457 | valid_loss=4.731612
# Epoch 029 | train_loss=4.846674 | valid_loss=4.709854
# Epoch 030 | train_loss=4.649415 | valid_loss=4.837190
# Epoch 031 | train_loss=4.782554 | valid_loss=4.795334
# Epoch 032 | train_loss=4.602487 | valid_loss=4.712525
# Epoch 033 | train_loss=4.628643 | valid_loss=4.747975
# Epoch 034 | train_loss=4.612271 | valid_loss=4.611572
# Epoch 035 | train_loss=4.887610 | valid_loss=4.721899
# Epoch 036 | train_loss=4.530229 | valid_loss=4.851674
# Epoch 037 | train_loss=4.669554 | valid_loss=5.112364
# Epoch 038 | train_loss=4.796506 | valid_loss=4.725183
# Epoch 039 | train_loss=4.575557 | valid_loss=4.849774
# Epoch 040 | train_loss=4.641518 | valid_loss=4.759799
# Epoch 041 | train_loss=4.602179 | valid_loss=4.637473
# Epoch 042 | train_loss=4.710374 | valid_loss=4.648133
# Epoch 043 | train_loss=4.426066 | valid_loss=4.629402
# Epoch 044 | train_loss=4.343316 | valid_loss=4.717126
# Epoch 045 | train_loss=4.721923 | valid_loss=4.659925
# Epoch 046 | train_loss=4.507529 | valid_loss=4.637554
# Epoch 047 | train_loss=4.525545 | valid_loss=4.596184
# Epoch 048 | train_loss=4.404590 | valid_loss=4.626543
# Epoch 049 | train_loss=4.377048 | valid_loss=4.634673
# Epoch 050 | train_loss=4.537099 | valid_loss=4.661523
# seed: 42, best_epoch 47, energy_mae: 0.689026415348053
#
# duration: 1504.024845123291
#
# Epoch 001 | train_loss=10.527240 | valid_loss=8.563691
# Epoch 002 | train_loss=7.537033 | valid_loss=6.582742
# Epoch 003 | train_loss=6.266239 | valid_loss=5.894227
# Epoch 004 | train_loss=5.620585 | valid_loss=5.500101
# Epoch 005 | train_loss=5.355658 | valid_loss=5.304184
# Epoch 006 | train_loss=5.204436 | valid_loss=5.187711
# Epoch 007 | train_loss=5.133264 | valid_loss=5.106833
# Epoch 008 | train_loss=4.832025 | valid_loss=4.878497
# Epoch 009 | train_loss=4.870949 | valid_loss=4.940369
# Epoch 010 | train_loss=4.834980 | valid_loss=4.855406
# Epoch 011 | train_loss=4.847966 | valid_loss=4.857980
# Epoch 012 | train_loss=4.723737 | valid_loss=4.873226
# Epoch 013 | train_loss=4.854799 | valid_loss=4.855699
# Epoch 014 | train_loss=4.687518 | valid_loss=4.912969
# Epoch 015 | train_loss=4.847578 | valid_loss=4.908925
# Epoch 016 | train_loss=5.131001 | valid_loss=4.820778
# Epoch 017 | train_loss=4.782255 | valid_loss=4.985087
# Epoch 018 | train_loss=4.712794 | valid_loss=4.866500
# Epoch 019 | train_loss=4.836512 | valid_loss=4.793995
# Epoch 020 | train_loss=4.983973 | valid_loss=4.891097
# Epoch 021 | train_loss=4.978523 | valid_loss=4.918188
# Epoch 022 | train_loss=4.683795 | valid_loss=4.729708
# Epoch 023 | train_loss=4.598490 | valid_loss=4.853384
# Epoch 024 | train_loss=4.792831 | valid_loss=4.753111
# Epoch 025 | train_loss=4.913115 | valid_loss=4.858421
# Epoch 026 | train_loss=4.891883 | valid_loss=4.889325
# Epoch 027 | train_loss=4.807261 | valid_loss=4.963874
# Epoch 028 | train_loss=4.735577 | valid_loss=4.754491
# Epoch 029 | train_loss=4.808560 | valid_loss=5.010199
# Epoch 030 | train_loss=4.905705 | valid_loss=5.059593
# Epoch 031 | train_loss=5.206089 | valid_loss=5.434451
# Epoch 032 | train_loss=5.084467 | valid_loss=4.918856
# Epoch 033 | train_loss=4.616046 | valid_loss=5.079795
# Epoch 034 | train_loss=5.381730 | valid_loss=4.780280
# Epoch 035 | train_loss=4.776070 | valid_loss=4.693419
# Epoch 036 | train_loss=4.551364 | valid_loss=4.970853
# Epoch 037 | train_loss=4.890431 | valid_loss=4.652011
# Epoch 038 | train_loss=4.691362 | valid_loss=4.663149
# Epoch 039 | train_loss=4.846235 | valid_loss=4.734995
# Epoch 040 | train_loss=4.612751 | valid_loss=4.886920
# Epoch 041 | train_loss=4.872079 | valid_loss=4.870453
# Epoch 042 | train_loss=4.611309 | valid_loss=5.020705
# Epoch 043 | train_loss=4.720269 | valid_loss=4.808861
# Epoch 044 | train_loss=4.644645 | valid_loss=4.617885
# Epoch 045 | train_loss=4.649571 | valid_loss=4.630407
# Epoch 046 | train_loss=4.702922 | valid_loss=4.624587
# Epoch 047 | train_loss=4.572987 | valid_loss=4.650641
# Epoch 048 | train_loss=4.752851 | valid_loss=5.081895
# Epoch 049 | train_loss=4.881326 | valid_loss=4.925524
# Epoch 050 | train_loss=4.675093 | valid_loss=4.801607
# seed: 42, best_epoch 44, energy_mae: 0.687936007976532
#
# duration: 1609.0920550823212
#
# Epoch 001 | train_loss=10.963252 | valid_loss=8.818091
# Epoch 002 | train_loss=8.320704 | valid_loss=7.007210
# Epoch 003 | train_loss=6.614601 | valid_loss=5.780035
# Epoch 004 | train_loss=5.581461 | valid_loss=5.436261
# Epoch 005 | train_loss=5.464192 | valid_loss=5.310408
# Epoch 006 | train_loss=5.182950 | valid_loss=5.227381
# Epoch 007 | train_loss=5.620572 | valid_loss=5.028923
# Epoch 008 | train_loss=4.998831 | valid_loss=4.942413
# Epoch 009 | train_loss=5.084237 | valid_loss=5.098492
# Epoch 010 | train_loss=5.003210 | valid_loss=4.862075
# Epoch 011 | train_loss=4.944527 | valid_loss=4.913634
# Epoch 012 | train_loss=5.060262 | valid_loss=4.971057
# Epoch 013 | train_loss=5.042818 | valid_loss=5.007298
# Epoch 014 | train_loss=5.087379 | valid_loss=4.812979
# Epoch 015 | train_loss=4.861867 | valid_loss=4.793267
# Epoch 016 | train_loss=4.843590 | valid_loss=4.742503
# Epoch 017 | train_loss=5.485345 | valid_loss=4.801046
# Epoch 018 | train_loss=4.727848 | valid_loss=4.732860
# Epoch 019 | train_loss=4.752839 | valid_loss=4.751961
# Epoch 020 | train_loss=4.819482 | valid_loss=4.878160
# Epoch 021 | train_loss=4.829708 | valid_loss=4.889079
# Epoch 022 | train_loss=4.668665 | valid_loss=4.682237
# Epoch 023 | train_loss=4.783616 | valid_loss=4.661457
# Epoch 024 | train_loss=4.732843 | valid_loss=4.684642
# Epoch 025 | train_loss=4.788948 | valid_loss=4.718626
# Epoch 026 | train_loss=4.665445 | valid_loss=4.763959
# Epoch 027 | train_loss=4.636957 | valid_loss=4.619331
# Epoch 028 | train_loss=4.663050 | valid_loss=4.606397
# Epoch 029 | train_loss=4.658679 | valid_loss=4.637525
# Epoch 030 | train_loss=4.589228 | valid_loss=4.650465
# Epoch 031 | train_loss=4.652678 | valid_loss=4.752334
# Epoch 032 | train_loss=4.714581 | valid_loss=4.881303
# Epoch 033 | train_loss=4.878714 | valid_loss=4.960447
# Epoch 034 | train_loss=4.735663 | valid_loss=4.781946
# Epoch 035 | train_loss=4.729714 | valid_loss=5.335212
# Epoch 036 | train_loss=4.759923 | valid_loss=4.671631
# Epoch 037 | train_loss=4.711759 | valid_loss=4.615322
# Epoch 038 | train_loss=4.646703 | valid_loss=4.712608
# Epoch 039 | train_loss=4.648819 | valid_loss=4.593914
# Epoch 040 | train_loss=4.578475 | valid_loss=4.662579
# Epoch 041 | train_loss=4.730360 | valid_loss=4.601418
# Epoch 042 | train_loss=4.658698 | valid_loss=4.678422
# Epoch 043 | train_loss=4.796392 | valid_loss=4.666250
# Epoch 044 | train_loss=4.678696 | valid_loss=4.892773
# Epoch 045 | train_loss=4.696308 | valid_loss=4.744765
# Epoch 046 | train_loss=4.605924 | valid_loss=4.659452
# Epoch 047 | train_loss=4.684503 | valid_loss=4.733689
# Epoch 048 | train_loss=4.701903 | valid_loss=4.710438
# Epoch 049 | train_loss=4.477425 | valid_loss=4.593177
# Epoch 050 | train_loss=5.381861 | valid_loss=4.637608
# seed: 42, best_epoch 49, energy_mae: 0.719124436378479
#
# duration: 1559.3318603038788
#
# Epoch 001 | train_loss=10.728222 | valid_loss=8.402068
# Epoch 002 | train_loss=7.715800 | valid_loss=6.937108
# Epoch 003 | train_loss=6.836124 | valid_loss=6.525482
# Epoch 004 | train_loss=5.948409 | valid_loss=5.843373
# Epoch 005 | train_loss=5.417985 | valid_loss=5.388789
# Epoch 006 | train_loss=5.650871 | valid_loss=5.089225
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 32
#      28     # do the training
#      29     transfer_model = NaiveStrategy().apply(base_model)
#      30     transfer_optimizer = torch.optim.Adam(transfer_model.parameters(), lr=TRANSFER_LR)
#      31
# ---> 32     transfer_model, transfer_history = trainer.train_model(
#      33         transfer_model, transfer_train_loader, full_valid_loader, transfer_optimizer, loss_fn
#      34     )
#      35
#
# File ~/X-MACE-TL/mace/training/trainer.py:58, in Trainer.train_model(self, model, train_loader, valid_loader, optimizer, loss_fn)
#      55 patience_counter = 0
#      57 for epoch in range(1, self.max_epochs + 1):
# ---> 58     train_loss = self._run_epoch(
#      59         model, train_loader, optimizer, loss_fn, training=True
#      60     )
#      61     valid_loss = self._run_epoch(
#      62         model, valid_loader, optimizer, loss_fn, training=False
#      63     )
#      65     history["epoch"].append(epoch)
#
# File ~/X-MACE-TL/mace/training/trainer.py:146, in Trainer._run_epoch(self, model, data_loader, optimizer, loss_fn, training)
#     143 loss = loss_fn(pred=output, ref=batch)
#     145 if training:
# --> 146     loss.backward()
#     147     # Gradient clipping
#     148     if self.max_grad_norm is not None:
#
# File ~/micromamba/envs/xmace311/lib/python3.11/site-packages/torch/_tensor.py:631, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     621 if has_torch_function_unary(self):
#     622     return handle_torch_function(
#     623         Tensor.backward,
#     624         (self,),
#    (...)    629         inputs=inputs,
#     630     )
# --> 631 torch.autograd.backward(
#     632     self, gradient, retain_graph, create_graph, inputs=inputs
#     633 )
#
# File ~/micromamba/envs/xmace311/lib/python3.11/site-packages/torch/autograd/__init__.py:379, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     374     retain_graph = create_graph
#     376 # The reason we repeat the same comment below is that
#     377 # some Python versions print out the first line of a multi-line function
#     378 # calls in the traceback and some print out the last line
# --> 379 _engine_run_backward(
#     380     tensors,
#     381     grad_tensors_,
#     382     retain_graph,
#     383     create_graph,
#     384     inputs_tuple,
#     385     allow_unreachable=True,
#     386     accumulate_grad=True,
#     387 )
#
# File ~/micromamba/envs/xmace311/lib/python3.11/site-packages/torch/autograd/graph.py:882, in _engine_run_backward(t_outputs, *args, **kwargs)
#     879 torch._C._stash_obj_in_tls("context", contextvars.copy_context())
#     881 try:
# --> 882     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     883         t_outputs, *args, **kwargs
#     884     )  # Calls into the C++ engine to run the backward pass
#     885 finally:
#     886     if attach_logging_hooks:
#
# KeyboardInterrupt:

# %% [markdown]
# ## 4. Plot

# %%
# Save results to CSV
import pandas as pd

ROOT_PATH = Path.cwd()
OUTPUT_DIR = ROOT_PATH / '../outputs'
RESULTS_CSV = OUTPUT_DIR / 'results' / 'repeated_runs_copy_results.csv'

results_df = pd.DataFrame(results)
results_df.to_csv(RESULTS_CSV, index=False)
print(f'Results saved to {RESULTS_CSV}')
# Out:
# Results saved to /home/lim_yt/X-MACE-sampling/notebooks/../outputs/results/repeated_runs_copy_results.csv

# %%
print(results_df)
# Out:
#     seed  best_epoch  energy_mae
# 0     42          47    0.688577
# 1     42          46    0.682953
# 2     42          41    0.680781
# 3     42          44    0.679309
# 4     42          45    0.677656
# 5     42          48    0.667467
# 6     42          50    0.679838
# 7     42          43    0.691280
# 8     42          49    0.664295
# 9     42          46    0.668880
# 10    42          47    0.689026
# 11    42          44    0.687936
# 12    42          49    0.719124

# %%
import matplotlib.pyplot as plt

best_epochs = results_df["best_epoch"]
energy_maes = results_df["energy_mae"]

print("--- Best epochs ---")
print(len(best_epochs))
print("Mean:", np.mean(best_epochs))
print("Population stdev:", np.std(best_epochs))
print("Sample stdev:", np.std(best_epochs, ddof=1))

plt.hist(best_epochs, bins=30, color='skyblue', edgecolor='black')

plt.title(f'{len(results)} repeats\nBest epochs')
plt.xlabel('Values')
plt.ylabel('Frequency')

plt.show()

print("--- Energy MAEs ---")
print(len(energy_maes))
print("Mean:", np.mean(energy_maes))
print("Population stdev:", np.std(energy_maes))
print("Sample stdev:", np.std(energy_maes, ddof=1))

plt.hist(energy_maes, bins=30, color='skyblue', edgecolor='black')

plt.title(f'{len(results)} repeats\nEnergy MAEs')
plt.xlabel('Values')
plt.ylabel('Frequency')

plt.show()
# Out:
# --- Best epochs ---
# 13
# Mean: 46.07692307692308
# Population stdev: 2.5256084860587698
# Sample stdev: 2.6287366566958377
# --- Energy MAEs ---
# 13
# Mean: 0.6828556244189923
# Population stdev: 0.013337866829553003
# Sample stdev: 0.013882491942243816
